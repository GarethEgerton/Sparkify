# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import importlib
import os
import glob
import psycopg2
import pandas as pd
import sql_queries
from sql_queries import *

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# %%
# !python create_tables.py

# %%
conn = psycopg2.connect(
    database="sparkify",
    user="postgres",
    password="postrgres",
    host="localhost",
    port='5432'
)

# %%
cur = conn.cursor()

# %%
def get_files(filepath):
    '''
    Returns list of all files within the specified file path   
    '''
        
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('C:\\Users\\garet\\sparkify\\data\\song_data')

# %%
song_files
# Out:
# ['C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAAW128F429D538.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAABD128F429CF47.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAADZ128F9348C2E.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAEF128F4273421.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAFD128F92F423A.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAMO128F1481E7F.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAMQ128F1460CD3.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAPK128E0786D96.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAARJ128F9320760.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAVG12903CFA543.json',
#  'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAVO128F93133D4.json',
# ...

# %%
filepath = 'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAAW128F429D538.json'

# %%
filepath
# Out:
# 'C:\\Users\\garet\\sparkify\\data\\song_data\\A\\A\\A\\TRAAAAW128F429D538.json'

# %%
df = pd.DataFrame(columns=['num_songs', 'artist_id', 'artist_latitude', 'artist_longitude',
       'artist_location', 'artist_name', 'song_id', 'title', 'duration',
       'year'])

# %%
for song_file in song_files:
    df2 = pd.read_json(song_file, lines=True)
    df = pd.concat([df, df2])

# %%
df
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
# 0          1  ARMJAGH1187FB546F3         35.14968         -90.04892
# 0          1  ARKRRTF1187B9984DA              NaN               NaN
# 0          1  AR7G5I41187FB4CE6C              NaN               NaN
# 0          1  ARXR32B1187FB57099              NaN               NaN
# ..       ...                 ...              ...               ...
# 0          1  AR8IEZO1187B99055E              NaN               NaN
# 0          1  AR558FS1187FB45658              NaN               NaN
# 0          1  ARVBRGZ1187FB4675A              NaN               NaN
# 0          1  ARWB3G61187FB49404              NaN               NaN
# 0          1  AREVWGE1187B9B890A        -13.44200         -41.99520
#
#     artist_location       artist_name             song_id             title  \
# ...

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id', 'title', 'artist_id', 'year', 'duration']].values

# %%
song_data
# Out:
# array([['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1',
#         0, 218.93179],
#        ['SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969,
#         148.03546],
#        ['SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0,
#         177.47546],
#        ['SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C',
#         1982, 233.40363],
#        ['SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099',
#         2007, 209.60608],
#        ['SOYMRWW12A6D4FAB14',
#         'The Moon And I (Ordinary Day Album Version)',
#         'ARKFYS91187B98E58F', 0, 267.7024],
#        ['SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)',
#         'ARD0S291187B9B7BF5', 0, 114.78159],
#        ['SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0,
#         189.57016],
#        ['SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984,
#         269.81832],
#        ['SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)',
# ...

# %%
#!python create_tables.py

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
for row in song_data:
    cur.execute(song_table_insert, row)
    conn.commit()

# %%
#cur.execute('REVOKE CONNECT ON DATABASE sparkify FROM public')

# %%
#cur.execute('''SELECT pg_terminate_backend(pg_stat_activity.pid)
#                 FROM pg_stat_activity
#                 WHERE pg_stat_activity.datname = 'sparkify' ''')

# %%
df_query = pd.read_sql('select * from songs', conn)
df_query
# Out:
#                song_id             title           artist_id  year   duration
# 0   SOMZWCG12A8C13C480  I Didn't Mean To  ARD7TVE1187B99BFB1     0  218.93179
# 1   SOCIWDW12A8C13D406         Soul Deep  ARMJAGH1187FB546F3  1969  148.03546
# 2   SOXVLOJ12AB0189215   Amor De Cabaret  ARKRRTF1187B9984DA     0  177.47546
# 3   SONHOTT12A8C13493C   Something Girls  AR7G5I41187FB4CE6C  1982  233.40363
# 4   SOFSOCN12A8C143F5D    Face the Ashes  ARXR32B1187FB57099  2007  209.60608
# ..                 ...               ...                 ...   ...        ...
# 66  SOINLJW12A8C13314C     City Slickers  AR8IEZO1187B99055E  2008  149.86404
# 67  SOGDBUF12A8C140FAA             Intro  AR558FS1187FB45658  2003   75.67628
# 68  SORRZGD12A6310DBC3    Harajuku Girls  ARVBRGZ1187FB4675A  2004  290.55955
# 69  SODAUVL12A8C13D184         Prognosis  ARWB3G61187FB49404  2000  363.85914
# 70  SOFCHDR12AB01866EF       Living Hell  AREVWGE1187B9B890A     0  282.43546
#
# [71 rows x 5 columns]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values
artist_data
# Out:
# array([['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan],
#        ['ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968,
#         -90.04892],
#        ['ARKRRTF1187B9984DA', 'Sonora Santanera', '', nan, nan],
#        ['AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan],
#        ['ARXR32B1187FB57099', 'Gob', '', nan, nan],
#        ['ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', nan, nan],
#        ['ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan],
#        ['AR10USD1187B99F3F1', 'Tweeterfriendly Music',
#         'Burlington, Ontario, Canada', nan, nan],
#        ['AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan],
#        ['ARNTLGG11E2835DDB9', 'Clp', '', nan, nan],
#        ['ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962,
#         -80.01955],
#        ['ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', nan, nan],
#        ['ARL7K851187B99ACD2', 'Andy Andy', '', nan, nan],
# ...

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
for row in artist_data:
    cur.execute(artist_table_insert, row)
    conn.commit()

# %%
df_query = pd.read_sql('select * from artists', conn)
df_query
# Out:
#              artist_id       artist_name         location  latitude  longitude
# 0   ARD7TVE1187B99BFB1            Casual  California - LA       NaN        NaN
# 1   ARMJAGH1187FB546F3      The Box Tops      Memphis, TN  35.14968  -90.04892
# 2   ARKRRTF1187B9984DA  Sonora Santanera                        NaN        NaN
# 3   AR7G5I41187FB4CE6C          Adam Ant  London, England       NaN        NaN
# 4   ARXR32B1187FB57099               Gob                        NaN        NaN
# ..                 ...               ...              ...       ...        ...
# 64  AR8IEZO1187B99055E      Marc Shaiman                        NaN        NaN
# 65  AR558FS1187FB45658           40 Grit                        NaN        NaN
# 66  ARVBRGZ1187FB4675A      Gwen Stefani                        NaN        NaN
# 67  ARWB3G61187FB49404       Steve Morse   Hamilton, Ohio       NaN        NaN
# 68  AREVWGE1187B9B890A        Bitter End        Noci (BA) -13.44200  -41.99520
#
# [69 rows x 5 columns]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('C:\\Users\\garet\\sparkify\\data\\log_data')

# %%
log_files
# Out:
# ['C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-01-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-02-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-03-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-04-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-05-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-06-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-07-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-08-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-09-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-10-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-11-events.json',
#  'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-12-events.json',
# ...

# %%
filepath = 'C:\\Users\\garet\\sparkify\\data\\log_data\\2018\\11\\2018-11-01-events.json'

# %%
df = pd.DataFrame(columns=['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
       'length', 'level', 'location', 'method', 'page', 'registration',
       'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'])

for log_file in log_files:
    df2 = pd.read_json(log_file, lines=True)
    df = pd.concat([df, df2])

# %%
df
# Out:
#                artist       auth firstName gender itemInSession lastName  \
# 0                None  Logged In    Walter      M             0     Frye
# 1                None  Logged In    Kaylee      F             0  Summers
# 2             Des'ree  Logged In    Kaylee      F             1  Summers
# 3                None  Logged In    Kaylee      F             2  Summers
# 4             Mr Oizo  Logged In    Kaylee      F             3  Summers
# ..                ...        ...       ...    ...           ...      ...
# 383        Timbiriche  Logged In     Rylan      M            58   George
# 384  A Perfect Circle  Logged In     Rylan      M            59   George
# 385          Anberlin  Logged In     Rylan      M            60   George
# 386              None  Logged In     Rylan      M            61   George
# 387         Deas Vail  Logged In    Elijah      M             0    Davis
#
#         length level                           location method       page  \
# ...

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df.page == 'NextSong']
df.head()
# Out:
#               artist       auth firstName gender itemInSession lastName  \
# 2            Des'ree  Logged In    Kaylee      F             1  Summers
# 4            Mr Oizo  Logged In    Kaylee      F             3  Summers
# 5         Tamba Trio  Logged In    Kaylee      F             4  Summers
# 6     The Mars Volta  Logged In    Kaylee      F             5  Summers
# 7  Infected Mushroom  Logged In    Kaylee      F             6  Summers
#
#       length level                     location method      page  \
# 2  246.30812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 4  144.03873  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 5  177.18812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 6  380.42077  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 7  440.26730  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
#
#     registration sessionId                          song status  \
# 2  1540344794796       139                  You Gotta Be    200
# ...

# %%
t = pd.to_datetime(df.ts, unit='ms')
t
# Out:
# 2     2018-11-01 21:01:46.796
# 4     2018-11-01 21:05:52.796
# 5     2018-11-01 21:08:16.796
# 6     2018-11-01 21:11:13.796
# 7     2018-11-01 21:17:33.796
#                 ...
# 382   2018-11-30 18:40:05.796
# 383   2018-11-30 18:44:36.796
# 384   2018-11-30 18:47:58.796
# 385   2018-11-30 18:51:24.796
# 387   2018-11-30 19:54:24.796
# Name: ts, Length: 6820, dtype: datetime64[ns]

# %%
time_data = [list(t.values), 
             list(t.dt.hour.values), 
             list(t.dt.day.values), 
             list(t.dt.week.values),
             list(t.dt.year.values), 
             list(t.dt.weekday.values)]

# %%
column_labels = ('time_stamp', 'hour', 'day', 'week', 'year', 'weekday')

# %%
time_df = pd.DataFrame({column_labels[i]:time_data[i] for i in range(6)})
time_df.head()
# Out:
#                time_stamp  hour  day  week  year  weekday
# 0 2018-11-01 21:01:46.796    21    1    44  2018        3
# 1 2018-11-01 21:05:52.796    21    1    44  2018        3
# 2 2018-11-01 21:08:16.796    21    1    44  2018        3
# 3 2018-11-01 21:11:13.796    21    1    44  2018        3
# 4 2018-11-01 21:17:33.796    21    1    44  2018        3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %%
df_query = pd.read_sql('select * from time', conn)
df_query
# Out:
#                    time_stamp  hour  day  week  year  weekday
# 0     2018-11-01 21:01:46.796    21    1    44  2018        3
# 1     2018-11-01 21:05:52.796    21    1    44  2018        3
# 2     2018-11-01 21:08:16.796    21    1    44  2018        3
# 3     2018-11-01 21:11:13.796    21    1    44  2018        3
# 4     2018-11-01 21:17:33.796    21    1    44  2018        3
# ...                       ...   ...  ...   ...   ...      ...
# 6808  2018-11-30 18:40:05.796    18   30    48  2018        4
# 6809  2018-11-30 18:44:36.796    18   30    48  2018        4
# 6810  2018-11-30 18:47:58.796    18   30    48  2018        4
# 6811  2018-11-30 18:51:24.796    18   30    48  2018        4
# 6812  2018-11-30 19:54:24.796    19   30    48  2018        4
#
# [6813 rows x 6 columns]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
user_df
# Out:
#     userId firstName lastName gender level
# 2        8    Kaylee  Summers      F  free
# 4        8    Kaylee  Summers      F  free
# 5        8    Kaylee  Summers      F  free
# 6        8    Kaylee  Summers      F  free
# 7        8    Kaylee  Summers      F  free
# ..     ...       ...      ...    ...   ...
# 382     16     Rylan   George      M  paid
# 383     16     Rylan   George      M  paid
# 384     16     Rylan   George      M  paid
# 385     16     Rylan   George      M  paid
# 387      5    Elijah    Davis      M  free
#
# [6820 rows x 5 columns]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %%
df_query = pd.read_sql('select * from users', conn)
df_query
# Out:
#     user_id firstname lastname gender level
# 0        76    Jayden    Duffy      F  free
# 1        81    Sienna    Colon      F  free
# 2        69  Anabelle  Simpson      F  free
# 3         4    Alivia  Terrell      F  free
# 4        73     Jacob    Klein      M  paid
# ..      ...       ...      ...    ...   ...
# 91       79     James   Martin      M  free
# 92       33   Bronson   Harris      M  free
# 93       22      Sean   Wilson      F  free
# 94       39    Walter     Frye      M  free
# 95       24     Layla  Griffin      F  paid
#
# [96 rows x 5 columns]

# %%
df.head()
# Out:
#               artist       auth firstName gender itemInSession lastName  \
# 2            Des'ree  Logged In    Kaylee      F             1  Summers
# 4            Mr Oizo  Logged In    Kaylee      F             3  Summers
# 5         Tamba Trio  Logged In    Kaylee      F             4  Summers
# 6     The Mars Volta  Logged In    Kaylee      F             5  Summers
# 7  Infected Mushroom  Logged In    Kaylee      F             6  Summers
#
#       length level                     location method      page  \
# 2  246.30812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 4  144.03873  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 5  177.18812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 6  380.42077  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 7  440.26730  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
#
#     registration sessionId                          song status  \
# 2  1540344794796       139                  You Gotta Be    200
# ...

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.ts = pd.to_datetime(df.ts, unit='ms')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df
# Out:
#                 artist       auth firstName gender itemInSession lastName  \
# 2              Des'ree  Logged In    Kaylee      F             1  Summers
# 4              Mr Oizo  Logged In    Kaylee      F             3  Summers
# 5           Tamba Trio  Logged In    Kaylee      F             4  Summers
# 6       The Mars Volta  Logged In    Kaylee      F             5  Summers
# 7    Infected Mushroom  Logged In    Kaylee      F             6  Summers
# ..                 ...        ...       ...    ...           ...      ...
# 382       Foo Fighters  Logged In     Rylan      M            57   George
# 383         Timbiriche  Logged In     Rylan      M            58   George
# 384   A Perfect Circle  Logged In     Rylan      M            59   George
# 385           Anberlin  Logged In     Rylan      M            60   George
# 387          Deas Vail  Logged In    Elijah      M             0    Davis
#
#         length level                     location method      page  \
# ...

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %%
df_query = pd.read_sql('SELECT * FROM songplay', conn)
df_query
# Out:
#                    time_stamp  user_id level song_id artist_id  session_id  \
# 0     2018-11-01 21:01:46.796        8  free    None      None         139
# 1     2018-11-01 21:05:52.796        8  free    None      None         139
# 2     2018-11-01 21:08:16.796        8  free    None      None         139
# 3     2018-11-01 21:11:13.796        8  free    None      None         139
# 4     2018-11-01 21:17:33.796        8  free    None      None         139
# ...                       ...      ...   ...     ...       ...         ...
# 6808  2018-11-30 18:40:05.796       16  paid    None      None        1076
# 6809  2018-11-30 18:44:36.796       16  paid    None      None        1076
# 6810  2018-11-30 18:47:58.796       16  paid    None      None        1076
# 6811  2018-11-30 18:51:24.796       16  paid    None      None        1076
# 6812  2018-11-30 19:54:24.796        5  free    None      None         985
#
#                          location
# ...

# %%
df_query.song_id.value_counts()
# Out:
# SOZCTXZ12AB0182364    1
# Name: song_id, dtype: int64

# %%
df_query.artist_id.value_counts()
# Out:
# AR5KOSW1187FB35FF4    1
# Name: artist_id, dtype: int64

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.

# %%
# !python create_tables.py

# %%
# !python etl.py

# %%
# checking results
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkify user=postgres password=p400dellpc")
cur = conn.cursor()

# %%
df_query = pd.read_sql('select * from songs', conn)
df_query

# %%
df_query = pd.read_sql('select * from artists', conn)
df_query

# %%
df_query = pd.read_sql('SELECT * FROM time', conn)
df_query

# %%
df_query = pd.read_sql('select * from users', conn)
df_query

# %%
df_query.level.value_counts()

# %%
df_query = pd.read_sql('SELECT * FROM songplay', conn)
df_query

# %%
df_query.song_id.value_counts()

# %%
df_query.artist_id.value_counts()
